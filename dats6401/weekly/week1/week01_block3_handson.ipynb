# %% [markdown]
# # Week 1 — Block 3: Hands-On (Foundations & Setup)
#
# **~30 min.** Reproduce the demo pipeline yourself.
#
# **Tasks:**
# 1. (~5 min) Environment check passes on YOUR machine
# 2. (~15 min) Load a dataset and make one **fully labeled** chart
# 3. (~10 min) Run the starter app; make one change

# %% [markdown]
# ## Task 1 — Environment check

# %%
# TODO: run the import/version check from the demo.
# Everything imports? You're done. Something fails? Flag the instructor NOW.

# %% [markdown]
# ## Task 2 — A labeled chart
#
# Use `px.data.tips()`, `px.data.gapminder()`, `px.data.iris()` — or any CSV you brought.

# %%
import plotly.express as px
import matplotlib.pyplot as plt

# TODO: load a dataset; print .shape and .head()

# %%
# TODO: one chart with ALL the anatomy:
#  - axis labels WITH units
#  - a title that states a FINDING (not "Figure 1")
# Any chart type; the labeling is the graded part.

# %% [markdown]
# **Check yourself:** cover the code, look only at the chart — could a stranger state your finding in one sentence?

# %% [markdown]
# ## Task 3 — Your first app
#
# 1. Open `app_starter.py` (this folder); read it — it's the demo app plus two TODOs.
# 2. Run it: `streamlit run app_starter.py`
# 3. Complete **one** TODO (swap in your dataset, or change the chart).
#
# **Before you leave:** chart labeled ✓ · app runs ✓ — that's the homework's skeleton (full spec in the Week 1 chapter).
