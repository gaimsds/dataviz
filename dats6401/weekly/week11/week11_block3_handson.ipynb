# %% [markdown]
# # Week 11 — Block 3: Hands-On (Consuming APIs)
#
# **~40 min.** Build a Streamlit client around a real API.
#
# **Tasks:**
# 1. (~15 min) Pick an API: the course endpoint (port 8001), [Open-Meteo](https://open-meteo.com/), or [REST Countries](https://restcountries.com/). Fetch it and parse the JSON into a DataFrame **in this notebook first**.
# 2. (~15 min) Move the working call into a copy of `client_starter.py`: add one widget that changes a request **parameter**, cache the fetch, visualize the response.
# 3. (~10 min) Break it on purpose: stop the server / mistype the URL. Make your app show a friendly `st.error` instead of a traceback.

# %%
import requests
import pandas as pd

# TODO Task 1: fetch your chosen API here.
# Pattern:  r = requests.get(URL, params={...}, timeout=10)
#           r.raise_for_status()
#           df = pd.DataFrame(<the right part of r.json()>)

# %%
# TODO Task 1b: prove it parsed — show df.head() and df.shape

# %% [markdown]
# **Checkpoint:** you have a DataFrame from a live endpoint. Now Tasks 2–3 happen in your copy of `client_starter.py` (see this folder). The grading checklist for the app:
#
# - [ ] a widget changes a **request parameter** (not just filters local data)
# - [ ] the fetch is wrapped in `@st.cache_data(ttl=...)`
# - [ ] a failed request shows `st.error(...)`, the app does not crash
#
# **Discussion (Block 4):** What did you cache and what ttl did you pick — and when would caching be *wrong*? (Hint: live scores vs. country lists.)
