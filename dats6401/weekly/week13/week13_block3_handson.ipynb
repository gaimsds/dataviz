# %% [markdown]
# # Week 13 — Block 3: Hands-On (ML/NLP Visualization)
#
# **~35 min.** You'll produce model-explanation visuals, then wire YOUR Week 12 server to a live Streamlit client.
#
# **Tasks:**
# 1. (~12 min) Train the iris model (or load your `model.joblib`) and produce a **confusion matrix** + **feature importance** chart.
# 2. (~18 min) Start YOUR Week 12 server. Run `app_live_predictions.py`, confirm the live loop works, then add **one** improvement (see TODOs in the file).
# 3. (~5 min) Add an honest-uncertainty touch: show the full probability distribution, not just the top class.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

iris = load_iris(as_frame=True)
X, y = iris.data, iris.target
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=42)
model = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_tr, y_tr)

# TODO Task 1a: confusion matrix with class-name labels
# TODO Task 1b: horizontal-bar feature importance

# %%
# TODO Task 3 (after the app works): call your server with one BORDERLINE flower
# (try sepal 5.5/2.8, petal 4.3/1.8 — a perfect 50/50 split!) and print the FULL probability distribution.
# What does ~55% vs ~99% confidence mean for how the app should present the answer?

# %% [markdown]
# **Discussion (Block 4):**
# 1. Your confusion matrix vs your feature importances — do they tell a consistent story?
# 2. The app shows a progress bar for confidence. Is that honest for a 3-class problem? What would be better?
# 3. This client→server→visualize loop **is** your final project's architecture. What's missing for *your* model?
