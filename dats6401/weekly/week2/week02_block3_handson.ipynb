# %% [markdown]
# # Week 2 — Block 3: Hands-On (Grammar & Design)
#
# **~35 min.** Three encodings of ONE question, channels defended.
#
# **Tasks:**
# 1. (~5 min) Pick a dataset + ONE question
# 2. (~20 min) Three encodings, at least one strong and one deliberately weak
# 3. (~10 min) Side-by-side in Streamlit (`app_compare_starter.py`)

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# TODO Task 1: pick px.data.tips(), .gapminder(), .iris() — or your own.
# Write your ONE question as a comment here:
# QUESTION:

# %%
# TODO Task 2a: Encoding 1 — the question's key comparison on POSITION.

# %%
# TODO Task 2b: Encoding 2 — same question, the comparison moved to a
# WEAKER channel (hue, area, or angle). Label it as the weak version.

# %%
# TODO Task 2c: Encoding 3 — your choice: faceting, redundant encoding,
# or a different mark. Aim for the most READABLE version of the three.

# %% [markdown]
# **For each encoding, one sentence in this cell:** which channel carries the main comparison, and where does it sit in the accuracy ranking?
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## Task 3 — Side by side in Streamlit
#
# Open `app_compare_starter.py`, drop two of your encodings into the marked slots, run it. The point: when charts sit in columns, readers compare *the encodings themselves* — your defense becomes visible.
#
# **Discussion (Block 4):** which weak encoding surprised you by being *less* terrible than the ranking predicts — and why might context (few categories? huge differences?) rescue a weak channel?
