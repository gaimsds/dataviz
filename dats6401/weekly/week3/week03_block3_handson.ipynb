# %% [markdown]
# # Week 3 — Block 3: Hands-On (Tabular & Multivariate)
#
# **~40 min.** The full multivariate pipeline on your data.
#
# Dataset: your own (≥6 numeric columns), or `load_wine` / `px.data.iris()`.
#
# **Tasks:**
# 1. (~10 min) Heatmap + ONE verified pair
# 2. (~15 min) Standardize → PCA → projection with explained variance on the axes
# 3. (~10 min) Loadings + one-sentence interpretation of PC1
# 4. (~5 min) Drop projection into `app_pca_starter.py`; add the color-by selector

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: load your dataset; keep a DataFrame `num` of ONLY numeric columns

# %%
# TODO Task 1: correlation heatmap (diverging cmap, centered at 0).
# Then pick the strongest off-diagonal pair and VERIFY with a scatter.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# TODO Task 2: standardize -> PCA(2) -> scatter
# REQUIRED: explained variance % in the axis labels.

# %%
# TODO Task 3: loadings bar chart for PC1.
# Then complete: "PC1 separates samples by ______"

# %% [markdown]
# **Check yourself:** wine should give ~36% + ~19%; iris ~73% + ~23%. If your PC1 is one variable's loadings only — did you standardize?
#
# ## Task 4 — the app
#
# `app_pca_starter.py` has the projection wired; add the **color-by selectbox** (the TODO inside). Run it, color by different columns, and notice which colorings *mean* something.
#
# **Discussion (Block 4):** your PC1 sentence — would a domain expert nod or object? What would change their mind?
