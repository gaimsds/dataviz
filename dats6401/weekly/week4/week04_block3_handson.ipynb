# %% [markdown]
# # Week 4 — Block 3: Hands-On (Time-Series)
#
# **~40 min.** The pipeline on a series of your own (any CSV with dates — stock prices, weather, steps) or stick with CO₂.
#
# **Tasks:**
# 1. (~10 min) Datetime index → two resolutions, plotted
# 2. (~10 min) ACF → period → matched rolling trend
# 3. (~10 min) Decomposition; one sentence on the residual
# 4. (~10 min) `app_resolution_starter.py`: wire the resolution selector

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# TODO: load your series. Make sure the index is a DatetimeIndex:
#   df.index = pd.to_datetime(df["date"])
# Fallback: co2 = sm.datasets.co2.load_pandas().data.dropna()

# %%
# TODO Task 1: resample to two resolutions; plot side by side.
# In a comment: which resolution suits which QUESTION?

# %%
from statsmodels.graphics.tsaplots import plot_acf
# TODO Task 2: plot_acf on the DIFFERENCED series; read off the period;
# rolling-mean with the matched window over the raw series.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
# TODO Task 3: decompose with your period. One sentence on the residual:
# RESIDUAL READS:

# %% [markdown]
# ## Task 4 — the app
#
# `app_resolution_starter.py` plots your series with a **resolution selectbox** half-wired. Finish the TODO, run it, switch resolutions, and watch the story change live — that's the Week 4 lesson as a widget.
#
# **Discussion (Block 4):** what honesty choice did your final chart force (window? truncation? resolution?), and how did you disclose it?
