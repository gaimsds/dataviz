# %% [markdown]
# # Week 7 — Block 3: Hands-On (Text Data)
#
# **~40 min.** Your corpus: song lyrics, abstracts, reviews, tweets — anything with ≥30 short documents. Fallback: the inline corpus from the demo (works, but small).
#
# **Tasks:**
# 1. (~10 min) Preprocess + sorted frequency bars; note ONE preprocessing choice that changed the result
# 2. (~10 min) TF–IDF: the 5 most distinctive terms of 2 different documents
# 3. (~10 min) Project the TF–IDF vectors to 2-D; label points; one honest caption
# 4. (~10 min) `app_topic_starter.py`: run, paste your corpus, extend one TODO

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# TODO: build `docs`, a list of strings (one per document).

# %%
# TODO Task 1: CountVectorizer (try stop_words=None vs "english") -> sorted bars.
# PREPROCESSING NOTE (one sentence):

# %%
# TODO Task 2: TfidfVectorizer -> for two documents, the top-5 distinctive terms.
# Hint: row = pd.Series(T[i].toarray()[0], index=tfv.get_feature_names_out())

# %%
from sklearn.decomposition import PCA
# TODO Task 3: PCA(2) on the TF-IDF matrix -> labeled scatter.
# CAPTION (must name transform + projection):

# %% [markdown]
# ## Task 4 — the app
#
# `app_topic_starter.py` is a TF–IDF explorer: paste documents, get distinctive-terms bars per doc. Run it, feed it your corpus, then extend ONE TODO (n-grams toggle, or a doc-similarity view).
#
# **Discussion (Block 4):** which preprocessing choice moved your results most — and would a reader of your final chart ever know you made it?
