# %% [markdown]
# # Week 8 — Block 3: Hands-On (Image Data)
#
# **~40 min.** Digits (or your own image folder via PIL).
#
# **Tasks:**
# 1. (~10 min) Montage of ONE class + the class-balance bar
# 2. (~10 min) Mean images; predict (in a comment) the 2 most confusable pairs
# 3. (~12 min) Occlusion saliency on a digit OTHER than 0; interpret the overlay
# 4. (~8 min) `app_image_browser_starter.py`: run + extend one TODO

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

digits = load_digits()

# TODO Task 1: a montage of 30 images of ONE class, and the balance bar chart.

# %%
# TODO Task 2: the 10 mean images.
# PREDICTION (before any model!): most confusable pairs are ____ and ____

# %%
from sklearn.linear_model import LogisticRegression
# TODO Task 3: occlusion saliency for a digit of your choice (not 0).
# Pattern from the demo: train -> baseline proba -> hide each pixel -> delta.
# INTERPRETATION (one sentence):

# %% [markdown]
# ## Task 4 — the app
#
# `app_image_browser_starter.py` browses the digits and shows per-image stats; it also accepts an uploaded image. Run it, then extend ONE TODO.
#
# **Discussion (Block 4):** did your Task-2 prediction match the saliency story? What would you check in the DATA if the model keyed on a corner?
