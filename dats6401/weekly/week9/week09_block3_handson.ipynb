# %% [markdown]
# # Week 9 — Block 3: Hands-On (Maps I)
#
# **~40 min.** The honest choropleth, with your choices **written down**.
#
# Data: the provided `data/` files, or your own GeoJSON + attribute CSV.
#
# **Tasks:**
# 1. (~8 min) Load, CRS check, join
# 2. (~12 min) Compute a rate with a DIFFERENT denominator than the demo (per 100k? per area — `gdf.geometry.area`?); map counts vs your rate
# 3. (~12 min) Three classification schemes side by side; pick one, justify in a sentence
# 4. (~8 min) The disclosure block (bottom cell)

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# TODO Task 1: read data/counties.geojson, set CRS explicitly, merge data/county_stats.csv

# %%
# TODO Task 2: a new rate column (different denominator!) ->
# two maps side by side: count vs YOUR rate. Print top-3 by each.

# %%
# TODO Task 3: same rate, three schemes ("quantiles", "equal_interval",
# "natural_breaks"), k=5, side by side. Each title shows the scheme.
# JUSTIFICATION (one sentence — which scheme and why for THIS distribution):

# %% [markdown]
# ## Task 4 — The disclosure block
#
# Every map you ship this course ends with this block, filled in:
#
# ```
# PROJECTION/CRS: ____            (and why it's adequate for this map)
# NORMALIZATION:  ____ per ____   (and why this denominator)
# CLASSIFICATION: ____, k=____    (and why)
# MISSING DATA:   ____            (how shown)
# ```
#
# **Discussion (Block 4):** whose Task-2 denominator changed the top-3 most — and which denominator answers which *question*?
